# %% [markdown]
# # Cluster weekly transactions patterns
# Check [Deep Temporal Clustering : Fully Unsupervised Learning of Time-Domain Features](https://arxiv.org/abs/1802.01059v1) for more details on the approach.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load and inspect the transaction data

# %%
transactions = pd.read_csv('~/data/kkbox-churn/transactions.csv')
transactions.shape
# Out:
# (21547746, 9)

# %%
# %%time
transactions_per_user = [
    trans.sort_values('transaction_date')
    for _, trans in transactions.groupby('msno')
    if len(trans) >= 3
]
# Out:
# CPU times: user 5min 46s, sys: 2.74 s, total: 5min 49s
# Wall time: 5min 49s

# %%
transactions_per_user[np.random.choice(len(transactions_per_user))]
# Out:
#                                                   msno  payment_method_id  \
# 16461037  1kvk3pdve9uxdm3XXvn/BOPRo2b7GcRIB3cp3yiastI=                 41
# 1549942   1kvk3pdve9uxdm3XXvn/BOPRo2b7GcRIB3cp3yiastI=                 41
# 1780963   1kvk3pdve9uxdm3XXvn/BOPRo2b7GcRIB3cp3yiastI=                 41
# 14761499  1kvk3pdve9uxdm3XXvn/BOPRo2b7GcRIB3cp3yiastI=                 41
# 20751547  1kvk3pdve9uxdm3XXvn/BOPRo2b7GcRIB3cp3yiastI=                 41
# 10293244  1kvk3pdve9uxdm3XXvn/BOPRo2b7GcRIB3cp3yiastI=                 41
# 20249266  1kvk3pdve9uxdm3XXvn/BOPRo2b7GcRIB3cp3yiastI=                 41
# 17026439  1kvk3pdve9uxdm3XXvn/BOPRo2b7GcRIB3cp3yiastI=                 41
# 1254597   1kvk3pdve9uxdm3XXvn/BOPRo2b7GcRIB3cp3yiastI=                 41
# 5291400   1kvk3pdve9uxdm3XXvn/BOPRo2b7GcRIB3cp3yiastI=                 41
# 5002221   1kvk3pdve9uxdm3XXvn/BOPRo2b7GcRIB3cp3yiastI=                 41
# 21520418  1kvk3pdve9uxdm3XXvn/BOPRo2b7GcRIB3cp3yiastI=                 41
# ...

# %%
transactions.head()
# Out:
#                                            msno  payment_method_id  \
# 0  YyO+tlZtAXYXoZhNr3Vg3+dfVQvrBVGO8j1mfqe4ZHc=                 41
# 1  AZtu6Wl0gPojrEQYB8Q3vBSmE2wnZ3hi1FbK1rQQ0A4=                 41
# 2  UkDFI97Qb6+s2LWcijVVv4rMAsORbVDT2wNXF0aVbns=                 41
# 3  M1C56ijxozNaGD0t2h68PnH2xtx5iO5iR2MVYQB6nBI=                 39
# 4  yvj6zyBUaqdbUQSrKsrZ+xNDVM62knauSZJzakS9OW4=                 39
#
#    payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 0                 30              129                 129              1
# 1                 30              149                 149              1
# 2                 30              129                 129              1
# 3                 30              149                 149              1
# 4                 30              149                 149              1
#
#    transaction_date  membership_expire_date  is_cancel
# 0          20150930                20151101          0
# ...

# %% [markdown]
# ## Pre-process the data and split into weekly chunks

# %% [markdown]
# ## Define the autoencoder

# %% [markdown]
# ## Train and export the model

# %% [markdown]
# ## Visualize the clusters distribution and some of the results
